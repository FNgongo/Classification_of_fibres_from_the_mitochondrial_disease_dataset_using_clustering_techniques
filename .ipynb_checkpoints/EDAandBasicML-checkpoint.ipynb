# %%
# Necessary packages

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Specify where to save the processed files as savepath
#path = 'H:/Downloads/PhD-Atif/Warren_2019-master'

# %% [markdown]
# ## Loading the raw data

# %%
df = pd.read_csv('dat.txt', sep='\t', header=0)

# %%
df
# Out:
#              value   id channel patient_type patient_id  replicate  \
# 0         3.403409    1    SDHA      control        C02          1
# 1         3.664688    2    SDHA      control        C02          1
# 2         6.227979    3    SDHA      control        C02          1
# 3         3.478873    4    SDHA      control        C02          1
# 4         4.957944    5    SDHA      control        C02          1
# ...            ...  ...     ...          ...        ...        ...
# 245575  186.000000  751  yCoord      patient        P07          1
# 245576  141.000000  752  yCoord      patient        P07          1
# 245577  120.000000  753  yCoord      patient        P07          1
# 245578   99.000000  754  yCoord      patient        P07          1
# 245579   92.000000  755  yCoord      patient        P07          1
#
#        subject_group patrep_id      cell_id     colour            type
# 0            Control    C02R01  C02R01_0001  #0000FF0A  mean intensity
# 1            Control    C02R01  C02R01_0002  #0000FF0A  mean intensity
# 2            Control    C02R01  C02R01_0003  #0000FF0A  mean intensity
# 3            Control    C02R01  C02R01_0004  #0000FF0A  mean intensity
# 4            Control    C02R01  C02R01_0005  #0000FF0A  mean intensity
# ...              ...       ...          ...        ...             ...
# 245575        MT-TL1    P07R01  P07R01_0751  #FF00000A  mean intensity
# 245576        MT-TL1    P07R01  P07R01_0752  #FF00000A  mean intensity
# 245577        MT-TL1    P07R01  P07R01_0753  #FF00000A  mean intensity
# 245578        MT-TL1    P07R01  P07R01_0754  #FF00000A  mean intensity
# 245579        MT-TL1    P07R01  P07R01_0755  #FF00000A  mean intensity
#
# [245580 rows x 11 columns]

# %% [markdown]
# ### Exploring the categorical columns

# %%
df_categorical = df[['channel','patient_type','patient_id','replicate','subject_group','patrep_id','colour','type']]

# %%
for col in df_categorical:
    print(df_categorical[col].unique())
# Out:
# ['SDHA' 'LOG_SDHA' 'MED_SDHA' 'NDUFB8' 'LOG_NDUFB8' 'MED_NDUFB8' 'OSCP'
#  'LOG_OSCP' 'MED_OSCP' 'GRIM19' 'LOG_GRIM19' 'MED_GRIM19' 'VDAC1'
#  'LOG_VDAC1' 'MED_VDAC1' 'COX4+4L2' 'LOG_COX4+4L2' 'MED_COX4+4L2' 'MTCO1'
#  'LOG_MTCO1' 'MED_MTCO1' 'UqCRC2' 'LOG_UqCRC2' 'MED_UqCRC2' 'Area'
#  'AspectRatio' 'Perimeter' 'Circularity' 'xCoord' 'yCoord']
# ['control' 'patient']
# ['C02' 'C01' 'C03' 'P10' 'P04' 'P02' 'P05' 'P01' 'P08' 'P03' 'P09' 'P07']
# [1]
# ['Control' 'MT-TW' 'Deletion' 'CI' 'MT-TL1' 'MT-TG' 'MT-TE']
# ['C02R01' 'C01R01' 'C03R01' 'P10R01' 'P04R01' 'P02R01' 'P05R01' 'P01R01'
#  'P08R01' 'P03R01' 'P09R01' 'P07R01']
# ['#0000FF0A' '#FF00000A']
# ['mean intensity' 'log mean intensity' 'median intensity' 'area'
#  'aspect ratio' 'perimeter' 'circularity']

# %%
df['channel'] = df['channel'].str.replace('GRIM19','NDUFA13')

# %%
df.channel.unique()
# Out:
# array(['SDHA', 'LOG_SDHA', 'MED_SDHA', 'NDUFB8', 'LOG_NDUFB8',
#        'MED_NDUFB8', 'OSCP', 'LOG_OSCP', 'MED_OSCP', 'NDUFA13',
#        'LOG_NDUFA13', 'MED_NDUFA13', 'VDAC1', 'LOG_VDAC1', 'MED_VDAC1',
#        'COX4+4L2', 'LOG_COX4+4L2', 'MED_COX4+4L2', 'MTCO1', 'LOG_MTCO1',
#        'MED_MTCO1', 'UqCRC2', 'LOG_UqCRC2', 'MED_UqCRC2', 'Area',
#        'AspectRatio', 'Perimeter', 'Circularity', 'xCoord', 'yCoord'],
#       dtype=object)

# %%
df.groupby('patient_id').cell_id.nunique()
# Out:
# patient_id
# C01     148
# C02     289
# C03     131
# P01     337
# P02     232
# P03    1361
# P04     879
# P05    1878
# P07     755
# P08     628
# P09     946
# P10     602
# Name: cell_id, dtype: int64

# %% [markdown]
# ## Reshaping the dataframe

# %%
#df1=df.pivot(index=['cell_id','subject_group'], columns = ['channel'],values =['value'])

df1= pd.pivot_table(df, index=['cell_id','patient_type','subject_group','patient_id','colour'], columns = ['channel'],values =['value'])

# %%
pd.set_option('display.max_columns', None)
df1
# Out:
#                                                               value  \
# channel                                                        Area
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A   879.0
# C01R01_0002 control      Control       C01        #0000FF0A  2556.0
# C01R01_0003 control      Control       C01        #0000FF0A  6432.0
# C01R01_0004 control      Control       C01        #0000FF0A  3072.0
# C01R01_0005 control      Control       C01        #0000FF0A  8734.5
# ...                                                             ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A  1858.0
# P10R01_0599 patient      MT-TW         P10        #FF00000A  3970.5
# P10R01_0600 patient      MT-TW         P10        #FF00000A  1458.0
# P10R01_0601 patient      MT-TW         P10        #FF00000A  1276.5
# P10R01_0602 patient      MT-TW         P10        #FF00000A  1339.5
#
#                                                                          \
# channel                                                     AspectRatio
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A    0.448980
# C01R01_0002 control      Control       C01        #0000FF0A    0.876923
# C01R01_0003 control      Control       C01        #0000FF0A    0.800000
# C01R01_0004 control      Control       C01        #0000FF0A    1.157143
# C01R01_0005 control      Control       C01        #0000FF0A    1.595238
# ...                                                                 ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A    2.000000
# P10R01_0599 patient      MT-TW         P10        #FF00000A    1.451613
# P10R01_0600 patient      MT-TW         P10        #FF00000A    2.900000
# P10R01_0601 patient      MT-TW         P10        #FF00000A    3.133333
# P10R01_0602 patient      MT-TW         P10        #FF00000A    1.555556
#
#                                                                         \
# channel                                                       COX4+4L2
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A   4.926230
# C01R01_0002 control      Control       C01        #0000FF0A   9.064356
# C01R01_0003 control      Control       C01        #0000FF0A   7.408696
# C01R01_0004 control      Control       C01        #0000FF0A   8.756881
# C01R01_0005 control      Control       C01        #0000FF0A   5.994460
# ...                                                                ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A   8.157025
# P10R01_0599 patient      MT-TW         P10        #FF00000A   8.354244
# P10R01_0600 patient      MT-TW         P10        #FF00000A  13.741228
# P10R01_0601 patient      MT-TW         P10        #FF00000A  15.060748
# P10R01_0602 patient      MT-TW         P10        #FF00000A   7.575000
#
#                                                                          \
# channel                                                     Circularity
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A    0.667624
# C01R01_0002 control      Control       C01        #0000FF0A    0.662271
# C01R01_0003 control      Control       C01        #0000FF0A    0.484423
# C01R01_0004 control      Control       C01        #0000FF0A    0.608063
# C01R01_0005 control      Control       C01        #0000FF0A    0.705084
# ...                                                                 ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A    0.240837
# P10R01_0599 patient      MT-TW         P10        #FF00000A    0.409971
# P10R01_0600 patient      MT-TW         P10        #FF00000A    0.198452
# P10R01_0601 patient      MT-TW         P10        #FF00000A    0.228461
# P10R01_0602 patient      MT-TW         P10        #FF00000A    0.240358
#
#                                                                           \
# channel                                                     LOG_COX4+4L2
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A     3.528312
# C01R01_0002 control      Control       C01        #0000FF0A     6.656274
# C01R01_0003 control      Control       C01        #0000FF0A     5.569829
# C01R01_0004 control      Control       C01        #0000FF0A     7.275473
# C01R01_0005 control      Control       C01        #0000FF0A     4.253457
# ...                                                                  ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A     6.455170
# P10R01_0599 patient      MT-TW         P10        #FF00000A     7.325609
# P10R01_0600 patient      MT-TW         P10        #FF00000A    11.432586
# P10R01_0601 patient      MT-TW         P10        #FF00000A    13.320255
# P10R01_0602 patient      MT-TW         P10        #FF00000A     6.022850
#
#                                                                        \
# channel                                                     LOG_MTCO1
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A  1.512562
# C01R01_0002 control      Control       C01        #0000FF0A  1.763175
# C01R01_0003 control      Control       C01        #0000FF0A  1.652074
# C01R01_0004 control      Control       C01        #0000FF0A  1.843152
# C01R01_0005 control      Control       C01        #0000FF0A  1.421162
# ...                                                               ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A  1.407893
# P10R01_0599 patient      MT-TW         P10        #FF00000A  1.150830
# P10R01_0600 patient      MT-TW         P10        #FF00000A  1.307792
# P10R01_0601 patient      MT-TW         P10        #FF00000A  1.817468
# P10R01_0602 patient      MT-TW         P10        #FF00000A  1.099100
#
#                                                                          \
# channel                                                     LOG_NDUFA13
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A    1.718303
# C01R01_0002 control      Control       C01        #0000FF0A    2.777602
# C01R01_0003 control      Control       C01        #0000FF0A    2.207175
# C01R01_0004 control      Control       C01        #0000FF0A    2.923391
# C01R01_0005 control      Control       C01        #0000FF0A    1.760127
# ...                                                                 ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A    1.904649
# P10R01_0599 patient      MT-TW         P10        #FF00000A    1.477179
# P10R01_0600 patient      MT-TW         P10        #FF00000A    1.628173
# P10R01_0601 patient      MT-TW         P10        #FF00000A    3.064791
# P10R01_0602 patient      MT-TW         P10        #FF00000A    1.324772
#
#                                                                         \
# channel                                                     LOG_NDUFB8
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A   1.926028
# C01R01_0002 control      Control       C01        #0000FF0A   2.671580
# C01R01_0003 control      Control       C01        #0000FF0A   2.160935
# C01R01_0004 control      Control       C01        #0000FF0A   2.566386
# C01R01_0005 control      Control       C01        #0000FF0A   1.769816
# ...                                                                ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A   1.519806
# P10R01_0599 patient      MT-TW         P10        #FF00000A   1.191700
# P10R01_0600 patient      MT-TW         P10        #FF00000A   1.312751
# P10R01_0601 patient      MT-TW         P10        #FF00000A   2.606018
# P10R01_0602 patient      MT-TW         P10        #FF00000A   1.206204
#
#                                                                         \
# channel                                                       LOG_OSCP
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A   2.092291
# C01R01_0002 control      Control       C01        #0000FF0A   2.926415
# C01R01_0003 control      Control       C01        #0000FF0A   2.409333
# C01R01_0004 control      Control       C01        #0000FF0A   2.976915
# C01R01_0005 control      Control       C01        #0000FF0A   2.003908
# ...                                                                ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A  10.240695
# P10R01_0599 patient      MT-TW         P10        #FF00000A  21.188446
# P10R01_0600 patient      MT-TW         P10        #FF00000A  40.187626
# P10R01_0601 patient      MT-TW         P10        #FF00000A   4.084146
# P10R01_0602 patient      MT-TW         P10        #FF00000A  14.693705
#
#                                                                         \
# channel                                                       LOG_SDHA
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A   2.498110
# C01R01_0002 control      Control       C01        #0000FF0A   4.195481
# C01R01_0003 control      Control       C01        #0000FF0A   3.632043
# C01R01_0004 control      Control       C01        #0000FF0A   4.496332
# C01R01_0005 control      Control       C01        #0000FF0A   2.789748
# ...                                                                ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A  13.661039
# P10R01_0599 patient      MT-TW         P10        #FF00000A  44.385100
# P10R01_0600 patient      MT-TW         P10        #FF00000A  63.152782
# P10R01_0601 patient      MT-TW         P10        #FF00000A   5.848844
# P10R01_0602 patient      MT-TW         P10        #FF00000A  33.566143
#
#                                                                         \
# channel                                                     LOG_UqCRC2
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A   2.793981
# C01R01_0002 control      Control       C01        #0000FF0A   4.720006
# C01R01_0003 control      Control       C01        #0000FF0A   3.797937
# C01R01_0004 control      Control       C01        #0000FF0A   4.825183
# C01R01_0005 control      Control       C01        #0000FF0A   2.704791
# ...                                                                ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A  10.582099
# P10R01_0599 patient      MT-TW         P10        #FF00000A  14.004130
# P10R01_0600 patient      MT-TW         P10        #FF00000A  28.195734
# P10R01_0601 patient      MT-TW         P10        #FF00000A   8.787500
# P10R01_0602 patient      MT-TW         P10        #FF00000A   9.559546
#
#                                                                        \
# channel                                                     LOG_VDAC1
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A  1.574617
# C01R01_0002 control      Control       C01        #0000FF0A  1.753394
# C01R01_0003 control      Control       C01        #0000FF0A  1.552955
# C01R01_0004 control      Control       C01        #0000FF0A  1.750554
# C01R01_0005 control      Control       C01        #0000FF0A  1.469509
# ...                                                               ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A  2.976675
# P10R01_0599 patient      MT-TW         P10        #FF00000A  5.544963
# P10R01_0600 patient      MT-TW         P10        #FF00000A  9.497522
# P10R01_0601 patient      MT-TW         P10        #FF00000A  2.405839
# P10R01_0602 patient      MT-TW         P10        #FF00000A  4.394516
#
#                                                                           \
# channel                                                     MED_COX4+4L2
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A          4.0
# C01R01_0002 control      Control       C01        #0000FF0A          7.0
# C01R01_0003 control      Control       C01        #0000FF0A          6.0
# C01R01_0004 control      Control       C01        #0000FF0A          8.0
# C01R01_0005 control      Control       C01        #0000FF0A          4.0
# ...                                                                  ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A          7.0
# P10R01_0599 patient      MT-TW         P10        #FF00000A          8.0
# P10R01_0600 patient      MT-TW         P10        #FF00000A         12.0
# P10R01_0601 patient      MT-TW         P10        #FF00000A         14.0
# P10R01_0602 patient      MT-TW         P10        #FF00000A          6.0
#
#                                                                        \
# channel                                                     MED_MTCO1
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A       1.0
# C01R01_0002 control      Control       C01        #0000FF0A       2.0
# C01R01_0003 control      Control       C01        #0000FF0A       2.0
# C01R01_0004 control      Control       C01        #0000FF0A       2.0
# C01R01_0005 control      Control       C01        #0000FF0A       1.0
# ...                                                               ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A       1.0
# P10R01_0599 patient      MT-TW         P10        #FF00000A       1.0
# P10R01_0600 patient      MT-TW         P10        #FF00000A       1.0
# P10R01_0601 patient      MT-TW         P10        #FF00000A       2.0
# P10R01_0602 patient      MT-TW         P10        #FF00000A       1.0
#
#                                                                          \
# channel                                                     MED_NDUFA13
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A         2.0
# C01R01_0002 control      Control       C01        #0000FF0A         3.0
# C01R01_0003 control      Control       C01        #0000FF0A         2.0
# C01R01_0004 control      Control       C01        #0000FF0A         3.0
# C01R01_0005 control      Control       C01        #0000FF0A         2.0
# ...                                                                 ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A         2.0
# P10R01_0599 patient      MT-TW         P10        #FF00000A         1.0
# P10R01_0600 patient      MT-TW         P10        #FF00000A         1.0
# P10R01_0601 patient      MT-TW         P10        #FF00000A         3.0
# P10R01_0602 patient      MT-TW         P10        #FF00000A         1.0
#
#                                                                         \
# channel                                                     MED_NDUFB8
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A        2.0
# C01R01_0002 control      Control       C01        #0000FF0A        3.0
# C01R01_0003 control      Control       C01        #0000FF0A        2.0
# C01R01_0004 control      Control       C01        #0000FF0A        3.0
# C01R01_0005 control      Control       C01        #0000FF0A        2.0
# ...                                                                ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A        1.0
# P10R01_0599 patient      MT-TW         P10        #FF00000A        1.0
# P10R01_0600 patient      MT-TW         P10        #FF00000A        1.0
# P10R01_0601 patient      MT-TW         P10        #FF00000A        3.0
# P10R01_0602 patient      MT-TW         P10        #FF00000A        1.0
#
#                                                                                \
# channel                                                     MED_OSCP MED_SDHA
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A      2.0      2.0
# C01R01_0002 control      Control       C01        #0000FF0A      3.0      4.0
# C01R01_0003 control      Control       C01        #0000FF0A      2.0      4.0
# C01R01_0004 control      Control       C01        #0000FF0A      3.0      5.0
# C01R01_0005 control      Control       C01        #0000FF0A      2.0      3.0
# ...                                                              ...      ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A     11.0     15.0
# P10R01_0599 patient      MT-TW         P10        #FF00000A     23.0     47.0
# P10R01_0600 patient      MT-TW         P10        #FF00000A     41.0     62.0
# P10R01_0601 patient      MT-TW         P10        #FF00000A      4.0      6.0
# P10R01_0602 patient      MT-TW         P10        #FF00000A     13.0     35.0
#
#                                                                         \
# channel                                                     MED_UqCRC2
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A        3.0
# C01R01_0002 control      Control       C01        #0000FF0A        5.0
# C01R01_0003 control      Control       C01        #0000FF0A        4.0
# C01R01_0004 control      Control       C01        #0000FF0A        5.0
# C01R01_0005 control      Control       C01        #0000FF0A        3.0
# ...                                                                ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A       10.0
# P10R01_0599 patient      MT-TW         P10        #FF00000A       15.0
# P10R01_0600 patient      MT-TW         P10        #FF00000A       30.0
# P10R01_0601 patient      MT-TW         P10        #FF00000A        9.0
# P10R01_0602 patient      MT-TW         P10        #FF00000A       10.0
#
#                                                                        \
# channel                                                     MED_VDAC1
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A       2.0
# C01R01_0002 control      Control       C01        #0000FF0A       2.0
# C01R01_0003 control      Control       C01        #0000FF0A       1.0
# C01R01_0004 control      Control       C01        #0000FF0A       2.0
# C01R01_0005 control      Control       C01        #0000FF0A       1.0
# ...                                                               ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A       3.0
# P10R01_0599 patient      MT-TW         P10        #FF00000A       6.0
# P10R01_0600 patient      MT-TW         P10        #FF00000A      10.0
# P10R01_0601 patient      MT-TW         P10        #FF00000A       2.0
# P10R01_0602 patient      MT-TW         P10        #FF00000A       4.0
#
#                                                                        \
# channel                                                         MTCO1
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A  1.737705
# C01R01_0002 control      Control       C01        #0000FF0A  2.143564
# C01R01_0003 control      Control       C01        #0000FF0A  1.918841
# C01R01_0004 control      Control       C01        #0000FF0A  2.165138
# C01R01_0005 control      Control       C01        #0000FF0A  1.617729
# ...                                                               ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A  1.574380
# P10R01_0599 patient      MT-TW         P10        #FF00000A  1.210332
# P10R01_0600 patient      MT-TW         P10        #FF00000A  1.434211
# P10R01_0601 patient      MT-TW         P10        #FF00000A  2.135514
# P10R01_0602 patient      MT-TW         P10        #FF00000A  1.160000
#
#                                                                        \
# channel                                                       NDUFA13
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A  2.122951
# C01R01_0002 control      Control       C01        #0000FF0A  3.608911
# C01R01_0003 control      Control       C01        #0000FF0A  2.739130
# C01R01_0004 control      Control       C01        #0000FF0A  3.577982
# C01R01_0005 control      Control       C01        #0000FF0A  2.227147
# ...                                                               ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A  2.371901
# P10R01_0599 patient      MT-TW         P10        #FF00000A  1.638376
# P10R01_0600 patient      MT-TW         P10        #FF00000A  1.925439
# P10R01_0601 patient      MT-TW         P10        #FF00000A  3.644860
# P10R01_0602 patient      MT-TW         P10        #FF00000A  1.480000
#
#                                                                        \
# channel                                                        NDUFB8
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A  2.409836
# C01R01_0002 control      Control       C01        #0000FF0A  3.301980
# C01R01_0003 control      Control       C01        #0000FF0A  2.646377
# C01R01_0004 control      Control       C01        #0000FF0A  3.077982
# C01R01_0005 control      Control       C01        #0000FF0A  2.160665
# ...                                                               ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A  1.768595
# P10R01_0599 patient      MT-TW         P10        #FF00000A  1.291513
# P10R01_0600 patient      MT-TW         P10        #FF00000A  1.434211
# P10R01_0601 patient      MT-TW         P10        #FF00000A  3.056075
# P10R01_0602 patient      MT-TW         P10        #FF00000A  1.295000
#
#                                                                         \
# channel                                                           OSCP
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A   2.573770
# C01R01_0002 control      Control       C01        #0000FF0A   3.752475
# C01R01_0003 control      Control       C01        #0000FF0A   2.968116
# C01R01_0004 control      Control       C01        #0000FF0A   3.550459
# C01R01_0005 control      Control       C01        #0000FF0A   2.509695
# ...                                                                ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A  12.285124
# P10R01_0599 patient      MT-TW         P10        #FF00000A  24.623616
# P10R01_0600 patient      MT-TW         P10        #FF00000A  48.171053
# P10R01_0601 patient      MT-TW         P10        #FF00000A   5.051402
# P10R01_0602 patient      MT-TW         P10        #FF00000A  22.290000
#
#                                                                          \
# channel                                                       Perimeter
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A  128.627417
# C01R01_0002 control      Control       C01        #0000FF0A  220.225396
# C01R01_0003 control      Control       C01        #0000FF0A  408.475175
# C01R01_0004 control      Control       C01        #0000FF0A  251.965509
# C01R01_0005 control      Control       C01        #0000FF0A  394.551296
# ...                                                                 ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A  311.362478
# P10R01_0599 patient      MT-TW         P10        #FF00000A  348.859952
# P10R01_0600 patient      MT-TW         P10        #FF00000A  303.847760
# P10R01_0601 patient      MT-TW         P10        #FF00000A  264.977702
# P10R01_0602 patient      MT-TW         P10        #FF00000A  264.634556
#
#                                                                         \
# channel                                                           SDHA
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A   3.131148
# C01R01_0002 control      Control       C01        #0000FF0A   5.202970
# C01R01_0003 control      Control       C01        #0000FF0A   4.539130
# C01R01_0004 control      Control       C01        #0000FF0A   5.399083
# C01R01_0005 control      Control       C01        #0000FF0A   3.684211
# ...                                                                ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A  16.578512
# P10R01_0599 patient      MT-TW         P10        #FF00000A  49.250923
# P10R01_0600 patient      MT-TW         P10        #FF00000A  73.495614
# P10R01_0601 patient      MT-TW         P10        #FF00000A   7.032710
# P10R01_0602 patient      MT-TW         P10        #FF00000A  47.520000
#
#                                                                         \
# channel                                                         UqCRC2
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A   3.377049
# C01R01_0002 control      Control       C01        #0000FF0A   5.737624
# C01R01_0003 control      Control       C01        #0000FF0A   4.681159
# C01R01_0004 control      Control       C01        #0000FF0A   5.678899
# C01R01_0005 control      Control       C01        #0000FF0A   3.498615
# ...                                                                ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A  12.888430
# P10R01_0599 patient      MT-TW         P10        #FF00000A  16.025830
# P10R01_0600 patient      MT-TW         P10        #FF00000A  32.982456
# P10R01_0601 patient      MT-TW         P10        #FF00000A  10.261682
# P10R01_0602 patient      MT-TW         P10        #FF00000A  14.080000
#
#                                                                         \
# channel                                                          VDAC1
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A   1.778689
# C01R01_0002 control      Control       C01        #0000FF0A   2.049505
# C01R01_0003 control      Control       C01        #0000FF0A   1.791304
# C01R01_0004 control      Control       C01        #0000FF0A   2.045872
# C01R01_0005 control      Control       C01        #0000FF0A   1.692521
# ...                                                                ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A   3.611570
# P10R01_0599 patient      MT-TW         P10        #FF00000A   6.483395
# P10R01_0600 patient      MT-TW         P10        #FF00000A  11.657895
# P10R01_0601 patient      MT-TW         P10        #FF00000A   2.957944
# P10R01_0602 patient      MT-TW         P10        #FF00000A   5.870000
#
#
# channel                                                      xCoord  yCoord
# cell_id     patient_type subject_group patient_id colour
# C01R01_0001 control      Control       C01        #0000FF0A   704.0  1710.0
# C01R01_0002 control      Control       C01        #0000FF0A   717.0  1651.0
# C01R01_0003 control      Control       C01        #0000FF0A   775.0  1647.0
# C01R01_0004 control      Control       C01        #0000FF0A   731.0  1595.0
# C01R01_0005 control      Control       C01        #0000FF0A   905.0  1570.0
# ...                                                             ...     ...
# P10R01_0598 patient      MT-TW         P10        #FF00000A  1135.0    91.0
# P10R01_0599 patient      MT-TW         P10        #FF00000A   910.0    88.0
# P10R01_0600 patient      MT-TW         P10        #FF00000A  1004.0    63.0
# P10R01_0601 patient      MT-TW         P10        #FF00000A  1079.0    58.0
# P10R01_0602 patient      MT-TW         P10        #FF00000A   836.0    59.0
#
# [8186 rows x 30 columns]

# %%
df2= df1.reset_index()

# %%
df2
# Out:
#              cell_id patient_type subject_group patient_id     colour   value  \
# channel                                                                  Area
# 0        C01R01_0001      control       Control        C01  #0000FF0A   879.0
# 1        C01R01_0002      control       Control        C01  #0000FF0A  2556.0
# 2        C01R01_0003      control       Control        C01  #0000FF0A  6432.0
# 3        C01R01_0004      control       Control        C01  #0000FF0A  3072.0
# 4        C01R01_0005      control       Control        C01  #0000FF0A  8734.5
# ...              ...          ...           ...        ...        ...     ...
# 8181     P10R01_0598      patient         MT-TW        P10  #FF00000A  1858.0
# 8182     P10R01_0599      patient         MT-TW        P10  #FF00000A  3970.5
# 8183     P10R01_0600      patient         MT-TW        P10  #FF00000A  1458.0
# 8184     P10R01_0601      patient         MT-TW        P10  #FF00000A  1276.5
# 8185     P10R01_0602      patient         MT-TW        P10  #FF00000A  1339.5
#
#                                                                                \
# channel AspectRatio   COX4+4L2 Circularity LOG_COX4+4L2 LOG_MTCO1 LOG_NDUFA13
# 0          0.448980   4.926230    0.667624     3.528312  1.512562    1.718303
# 1          0.876923   9.064356    0.662271     6.656274  1.763175    2.777602
# 2          0.800000   7.408696    0.484423     5.569829  1.652074    2.207175
# 3          1.157143   8.756881    0.608063     7.275473  1.843152    2.923391
# 4          1.595238   5.994460    0.705084     4.253457  1.421162    1.760127
# ...             ...        ...         ...          ...       ...         ...
# 8181       2.000000   8.157025    0.240837     6.455170  1.407893    1.904649
# 8182       1.451613   8.354244    0.409971     7.325609  1.150830    1.477179
# 8183       2.900000  13.741228    0.198452    11.432586  1.307792    1.628173
# 8184       3.133333  15.060748    0.228461    13.320255  1.817468    3.064791
# 8185       1.555556   7.575000    0.240358     6.022850  1.099100    1.324772
#
#                                                                             \
# channel LOG_NDUFB8   LOG_OSCP   LOG_SDHA LOG_UqCRC2 LOG_VDAC1 MED_COX4+4L2
# 0         1.926028   2.092291   2.498110   2.793981  1.574617          4.0
# 1         2.671580   2.926415   4.195481   4.720006  1.753394          7.0
# 2         2.160935   2.409333   3.632043   3.797937  1.552955          6.0
# 3         2.566386   2.976915   4.496332   4.825183  1.750554          8.0
# 4         1.769816   2.003908   2.789748   2.704791  1.469509          4.0
# ...            ...        ...        ...        ...       ...          ...
# 8181      1.519806  10.240695  13.661039  10.582099  2.976675          7.0
# 8182      1.191700  21.188446  44.385100  14.004130  5.544963          8.0
# 8183      1.312751  40.187626  63.152782  28.195734  9.497522         12.0
# 8184      2.606018   4.084146   5.848844   8.787500  2.405839         14.0
# 8185      1.206204  14.693705  33.566143   9.559546  4.394516          6.0
#
#                                                                        \
# channel MED_MTCO1 MED_NDUFA13 MED_NDUFB8 MED_OSCP MED_SDHA MED_UqCRC2
# 0             1.0         2.0        2.0      2.0      2.0        3.0
# 1             2.0         3.0        3.0      3.0      4.0        5.0
# 2             2.0         2.0        2.0      2.0      4.0        4.0
# 3             2.0         3.0        3.0      3.0      5.0        5.0
# 4             1.0         2.0        2.0      2.0      3.0        3.0
# ...           ...         ...        ...      ...      ...        ...
# 8181          1.0         2.0        1.0     11.0     15.0       10.0
# 8182          1.0         1.0        1.0     23.0     47.0       15.0
# 8183          1.0         1.0        1.0     41.0     62.0       30.0
# 8184          2.0         3.0        3.0      4.0      6.0        9.0
# 8185          1.0         1.0        1.0     13.0     35.0       10.0
#
#                                                                         \
# channel MED_VDAC1     MTCO1   NDUFA13    NDUFB8       OSCP   Perimeter
# 0             2.0  1.737705  2.122951  2.409836   2.573770  128.627417
# 1             2.0  2.143564  3.608911  3.301980   3.752475  220.225396
# 2             1.0  1.918841  2.739130  2.646377   2.968116  408.475175
# 3             2.0  2.165138  3.577982  3.077982   3.550459  251.965509
# 4             1.0  1.617729  2.227147  2.160665   2.509695  394.551296
# ...           ...       ...       ...       ...        ...         ...
# 8181          3.0  1.574380  2.371901  1.768595  12.285124  311.362478
# 8182          6.0  1.210332  1.638376  1.291513  24.623616  348.859952
# 8183         10.0  1.434211  1.925439  1.434211  48.171053  303.847760
# 8184          2.0  2.135514  3.644860  3.056075   5.051402  264.977702
# 8185          4.0  1.160000  1.480000  1.295000  22.290000  264.634556
#
#
# channel       SDHA     UqCRC2      VDAC1  xCoord  yCoord
# 0         3.131148   3.377049   1.778689   704.0  1710.0
# 1         5.202970   5.737624   2.049505   717.0  1651.0
# 2         4.539130   4.681159   1.791304   775.0  1647.0
# 3         5.399083   5.678899   2.045872   731.0  1595.0
# 4         3.684211   3.498615   1.692521   905.0  1570.0
# ...            ...        ...        ...     ...     ...
# 8181     16.578512  12.888430   3.611570  1135.0    91.0
# 8182     49.250923  16.025830   6.483395   910.0    88.0
# 8183     73.495614  32.982456  11.657895  1004.0    63.0
# 8184      7.032710  10.261682   2.957944  1079.0    58.0
# 8185     47.520000  14.080000   5.870000   836.0    59.0
#
# [8186 rows x 35 columns]

# %%
df2= df2.rename(columns={"value":""})

# %%
list(df2.columns)
# Out:
# [('cell_id', ''),
#  ('patient_type', ''),
#  ('subject_group', ''),
#  ('patient_id', ''),
#  ('colour', ''),
#  ('', 'Area'),
#  ('', 'AspectRatio'),
#  ('', 'COX4+4L2'),
#  ('', 'Circularity'),
#  ('', 'LOG_COX4+4L2'),
#  ('', 'LOG_MTCO1'),
#  ('', 'LOG_NDUFA13'),
#  ('', 'LOG_NDUFB8'),
#  ('', 'LOG_OSCP'),
#  ('', 'LOG_SDHA'),
#  ('', 'LOG_UqCRC2'),
#  ('', 'LOG_VDAC1'),
#  ('', 'MED_COX4+4L2'),
#  ('', 'MED_MTCO1'),
#  ('', 'MED_NDUFA13'),
#  ('', 'MED_NDUFB8'),
#  ('', 'MED_OSCP'),
#  ('', 'MED_SDHA'),
#  ('', 'MED_UqCRC2'),
#  ('', 'MED_VDAC1'),
#  ('', 'MTCO1'),
#  ('', 'NDUFA13'),
#  ('', 'NDUFB8'),
#  ('', 'OSCP'),
#  ('', 'Perimeter'),
#  ('', 'SDHA'),
#  ('', 'UqCRC2'),
#  ('', 'VDAC1'),
#  ('', 'xCoord'),
#  ('', 'yCoord')]

# %%
df2.columns = [f'{i}{j}' for i, j in df2.columns]
df2.columns = df2.columns.map(''.join)
#df2.columns = df2.columns.map('{0[0]}{0[1]}'.format)

# %%
df2
# Out:
#           cell_id patient_type subject_group patient_id     colour    Area  \
# 0     C01R01_0001      control       Control        C01  #0000FF0A   879.0
# 1     C01R01_0002      control       Control        C01  #0000FF0A  2556.0
# 2     C01R01_0003      control       Control        C01  #0000FF0A  6432.0
# 3     C01R01_0004      control       Control        C01  #0000FF0A  3072.0
# 4     C01R01_0005      control       Control        C01  #0000FF0A  8734.5
# ...           ...          ...           ...        ...        ...     ...
# 8181  P10R01_0598      patient         MT-TW        P10  #FF00000A  1858.0
# 8182  P10R01_0599      patient         MT-TW        P10  #FF00000A  3970.5
# 8183  P10R01_0600      patient         MT-TW        P10  #FF00000A  1458.0
# 8184  P10R01_0601      patient         MT-TW        P10  #FF00000A  1276.5
# 8185  P10R01_0602      patient         MT-TW        P10  #FF00000A  1339.5
#
#       AspectRatio   COX4+4L2  Circularity  LOG_COX4+4L2  LOG_MTCO1  \
# 0        0.448980   4.926230     0.667624      3.528312   1.512562
# 1        0.876923   9.064356     0.662271      6.656274   1.763175
# 2        0.800000   7.408696     0.484423      5.569829   1.652074
# 3        1.157143   8.756881     0.608063      7.275473   1.843152
# 4        1.595238   5.994460     0.705084      4.253457   1.421162
# ...           ...        ...          ...           ...        ...
# 8181     2.000000   8.157025     0.240837      6.455170   1.407893
# 8182     1.451613   8.354244     0.409971      7.325609   1.150830
# 8183     2.900000  13.741228     0.198452     11.432586   1.307792
# 8184     3.133333  15.060748     0.228461     13.320255   1.817468
# 8185     1.555556   7.575000     0.240358      6.022850   1.099100
#
#       LOG_NDUFA13  LOG_NDUFB8   LOG_OSCP   LOG_SDHA  LOG_UqCRC2  LOG_VDAC1  \
# 0        1.718303    1.926028   2.092291   2.498110    2.793981   1.574617
# 1        2.777602    2.671580   2.926415   4.195481    4.720006   1.753394
# 2        2.207175    2.160935   2.409333   3.632043    3.797937   1.552955
# 3        2.923391    2.566386   2.976915   4.496332    4.825183   1.750554
# 4        1.760127    1.769816   2.003908   2.789748    2.704791   1.469509
# ...           ...         ...        ...        ...         ...        ...
# 8181     1.904649    1.519806  10.240695  13.661039   10.582099   2.976675
# 8182     1.477179    1.191700  21.188446  44.385100   14.004130   5.544963
# 8183     1.628173    1.312751  40.187626  63.152782   28.195734   9.497522
# 8184     3.064791    2.606018   4.084146   5.848844    8.787500   2.405839
# 8185     1.324772    1.206204  14.693705  33.566143    9.559546   4.394516
#
#       MED_COX4+4L2  MED_MTCO1  MED_NDUFA13  MED_NDUFB8  MED_OSCP  MED_SDHA  \
# 0              4.0        1.0          2.0         2.0       2.0       2.0
# 1              7.0        2.0          3.0         3.0       3.0       4.0
# 2              6.0        2.0          2.0         2.0       2.0       4.0
# 3              8.0        2.0          3.0         3.0       3.0       5.0
# 4              4.0        1.0          2.0         2.0       2.0       3.0
# ...            ...        ...          ...         ...       ...       ...
# 8181           7.0        1.0          2.0         1.0      11.0      15.0
# 8182           8.0        1.0          1.0         1.0      23.0      47.0
# 8183          12.0        1.0          1.0         1.0      41.0      62.0
# 8184          14.0        2.0          3.0         3.0       4.0       6.0
# 8185           6.0        1.0          1.0         1.0      13.0      35.0
#
#       MED_UqCRC2  MED_VDAC1     MTCO1   NDUFA13    NDUFB8       OSCP  \
# 0            3.0        2.0  1.737705  2.122951  2.409836   2.573770
# 1            5.0        2.0  2.143564  3.608911  3.301980   3.752475
# 2            4.0        1.0  1.918841  2.739130  2.646377   2.968116
# 3            5.0        2.0  2.165138  3.577982  3.077982   3.550459
# 4            3.0        1.0  1.617729  2.227147  2.160665   2.509695
# ...          ...        ...       ...       ...       ...        ...
# 8181        10.0        3.0  1.574380  2.371901  1.768595  12.285124
# 8182        15.0        6.0  1.210332  1.638376  1.291513  24.623616
# 8183        30.0       10.0  1.434211  1.925439  1.434211  48.171053
# 8184         9.0        2.0  2.135514  3.644860  3.056075   5.051402
# 8185        10.0        4.0  1.160000  1.480000  1.295000  22.290000
#
#        Perimeter       SDHA     UqCRC2      VDAC1  xCoord  yCoord
# 0     128.627417   3.131148   3.377049   1.778689   704.0  1710.0
# 1     220.225396   5.202970   5.737624   2.049505   717.0  1651.0
# 2     408.475175   4.539130   4.681159   1.791304   775.0  1647.0
# 3     251.965509   5.399083   5.678899   2.045872   731.0  1595.0
# 4     394.551296   3.684211   3.498615   1.692521   905.0  1570.0
# ...          ...        ...        ...        ...     ...     ...
# 8181  311.362478  16.578512  12.888430   3.611570  1135.0    91.0
# 8182  348.859952  49.250923  16.025830   6.483395   910.0    88.0
# 8183  303.847760  73.495614  32.982456  11.657895  1004.0    63.0
# 8184  264.977702   7.032710  10.261682   2.957944  1079.0    58.0
# 8185  264.634556  47.520000  14.080000   5.870000   836.0    59.0
#
# [8186 rows x 35 columns]

# %% [markdown]
# ### Adding polar tranformation terms "Theta" & radius

# %%
df2['RADIUS_COX4+4L2']= ((df2['LOG_VDAC1']**(2))+(df2['LOG_COX4+4L2']**(2)))**(1/2)

# %%
df2['THETA_COX4+4L2']= (np.arctan((df2['LOG_COX4+4L2']/df2['LOG_VDAC1'])) ) *360 /(2*np.pi)

# %%
df2['RADIUS_MTCO1']= ((df2.LOG_VDAC1**(2))+(df2.LOG_MTCO1**(2)))**(1/2)
df2['THETA_MTCO1']= (np.arctan((df2.LOG_MTCO1/df2.LOG_VDAC1)) ) *360 /(2*np.pi)

df2['RADIUS_NDUFA13']= ((df2.LOG_VDAC1**(2))+(df2.LOG_NDUFA13**(2)))**(1/2)
df2['THETA_NDUFA13']= (np.arctan((df2.LOG_NDUFA13/df2.LOG_VDAC1)) ) *360 /(2*np.pi)

df2['RADIUS_NDUFB8']= ((df2.LOG_VDAC1**(2))+(df2.LOG_NDUFB8**(2)))**(1/2)
df2['THETA_NDUFB8']= (np.arctan((df2.LOG_NDUFB8/df2.LOG_VDAC1)) ) *360 /(2*np.pi)

df2['RADIUS_OSCP']= ((df2.LOG_VDAC1**(2))+(df2.LOG_OSCP**(2)))**(1/2)
df2['THETA_OSCP']= (np.arctan((df2.LOG_OSCP/df2.LOG_VDAC1)) ) *360 /(2*np.pi)

df2['RADIUS_SDHA']= ((df2.LOG_VDAC1**(2))+(df2.LOG_SDHA**(2)))**(1/2)
df2['THETA_SDHA']= (np.arctan((df2.LOG_SDHA/df2.LOG_VDAC1)) ) *360 /(2*np.pi)

df2['RADIUS_UqCRC2']= ((df2.LOG_VDAC1**(2))+(df2.LOG_UqCRC2**(2)))**(1/2)
df2['THETA_UqCRC2']= (np.arctan((df2.LOG_UqCRC2/df2.LOG_VDAC1)) ) *360 /(2*np.pi)

# %%
df2
# Out:
#           cell_id patient_type subject_group patient_id     colour    Area  \
# 0     C01R01_0001      control       Control        C01  #0000FF0A   879.0
# 1     C01R01_0002      control       Control        C01  #0000FF0A  2556.0
# 2     C01R01_0003      control       Control        C01  #0000FF0A  6432.0
# 3     C01R01_0004      control       Control        C01  #0000FF0A  3072.0
# 4     C01R01_0005      control       Control        C01  #0000FF0A  8734.5
# ...           ...          ...           ...        ...        ...     ...
# 8181  P10R01_0598      patient         MT-TW        P10  #FF00000A  1858.0
# 8182  P10R01_0599      patient         MT-TW        P10  #FF00000A  3970.5
# 8183  P10R01_0600      patient         MT-TW        P10  #FF00000A  1458.0
# 8184  P10R01_0601      patient         MT-TW        P10  #FF00000A  1276.5
# 8185  P10R01_0602      patient         MT-TW        P10  #FF00000A  1339.5
#
#       AspectRatio   COX4+4L2  Circularity  LOG_COX4+4L2  LOG_MTCO1  \
# 0        0.448980   4.926230     0.667624      3.528312   1.512562
# 1        0.876923   9.064356     0.662271      6.656274   1.763175
# 2        0.800000   7.408696     0.484423      5.569829   1.652074
# 3        1.157143   8.756881     0.608063      7.275473   1.843152
# 4        1.595238   5.994460     0.705084      4.253457   1.421162
# ...           ...        ...          ...           ...        ...
# 8181     2.000000   8.157025     0.240837      6.455170   1.407893
# 8182     1.451613   8.354244     0.409971      7.325609   1.150830
# 8183     2.900000  13.741228     0.198452     11.432586   1.307792
# 8184     3.133333  15.060748     0.228461     13.320255   1.817468
# 8185     1.555556   7.575000     0.240358      6.022850   1.099100
#
#       LOG_NDUFA13  LOG_NDUFB8   LOG_OSCP   LOG_SDHA  LOG_UqCRC2  LOG_VDAC1  \
# 0        1.718303    1.926028   2.092291   2.498110    2.793981   1.574617
# 1        2.777602    2.671580   2.926415   4.195481    4.720006   1.753394
# 2        2.207175    2.160935   2.409333   3.632043    3.797937   1.552955
# 3        2.923391    2.566386   2.976915   4.496332    4.825183   1.750554
# 4            4.500150       70.940694      2.044299    44.041803
# ...               ...             ...           ...          ...
# 8181         7.108432       65.244141      3.292834    25.312990
# 8182         9.187554       52.876878      5.663128    11.724998
# 8183        14.862939       50.282186      9.587139     7.840222
# 8184        13.535777       79.761894      3.015170    37.068866
# 8185         7.455635       53.883991      4.529878    14.042029
#
#       RADIUS_NDUFA13  THETA_NDUFA13  RADIUS_NDUFB8  THETA_NDUFB8  RADIUS_OSCP  \
# 0           2.330662      47.498496       2.487771     50.732414     2.618607
# 1           3.284732      57.737344       3.195580     56.722564     3.411495
# 2           2.698757      54.870020       2.661073     54.297107     2.866454
# 3           3.407441      59.086436       3.106569     55.701766     3.453471
# 4           2.292925      50.141895       2.300370     50.296555     2.484976
# ...              ...            ...            ...           ...          ...
# 8181        3.533876      32.613470       3.342215     27.047567    10.664541
# 8182        5.738351      14.917162       5.671575     12.129266    21.901983
# 8183        9.636071       9.727733       9.587817      7.869584    41.294651
# 8184        3.896281      51.868337       3.546743     47.287235     4.740075
# 8185        4.589858      16.775974       4.557049     15.348513    15.336777
#
#       THETA_OSCP  RADIUS_SDHA  THETA_SDHA  RADIUS_UqCRC2  THETA_UqCRC2
# 0      53.035596     2.952960   57.775808       3.207140     60.595488
# 1      59.071598     4.547137   67.318757       5.035161     69.620909
# 2      57.195878     3.950115   66.849875       4.103169     67.760627
# 3      59.542647     4.825084   68.727580       5.132916     70.059467
# 4      53.746603     3.153118   62.221833       3.078206     61.484830
# ...          ...          ...         ...            ...           ...
# 8181   73.792376    13.981580   77.707662      10.992789     74.289058
# 8182   75.334721    44.730121   82.879019      15.061948     68.398813
# 8183   76.703281    63.862953   81.447404      29.752350     71.384287
# 8184   59.499033     6.324321   67.640878       9.110885     74.688772
# 8185   73.349404    33.852588   82.541197      10.521249     65.311793
#
# [8186 rows x 49 columns]

# %%
df = df2

# %% [markdown]
# ## EDA

# %%
df_eda = df

# %%
df_eda.patient_type.value_counts().plot(kind='bar')

# %%
df_eda.subject_group.value_counts().plot(kind='bar')

# %%
df_eda.subject_group.value_counts()
# Out:
# MT-TL1      2633
# Deletion    2240
# MT-TE        946
# MT-TG        628
# MT-TW        602
# CI           569
# Control      568
# Name: subject_group, dtype: int64

# %%
ax = sns.scatterplot(x="Area", y="patient_id", hue="patient_type", palette='muted',data=df_eda)

# %%
ax = sns.scatterplot(x="Circularity", y="patient_id", hue="patient_type", palette='muted',data=df_eda)

# %%
ax = sns.scatterplot(x="LOG_VDAC1", y="LOG_COX4+4L2", hue="patient_type", palette='muted',data=df_eda)

# %%
ax = sns.scatterplot(x="LOG_VDAC1", y="LOG_MTCO1", hue="patient_type", palette=['green','red'], data=df_eda)

# %%
ax = sns.scatterplot(x="LOG_VDAC1", y="LOG_NDUFA13", hue="patient_type",palette='colorblind', data=df_eda)

# %%
ax = sns.scatterplot(x="LOG_VDAC1", y="LOG_NDUFB8", hue="patient_type", data=df_eda)

# %%
ax = sns.scatterplot(x="LOG_VDAC1", y="LOG_OSCP", hue="patient_type", data=df_eda)

# %%
ax = sns.scatterplot(x="LOG_VDAC1", y="LOG_SDHA", hue="patient_type", data=df_eda)

# %%
ax = sns.scatterplot(x="LOG_VDAC1", y="LOG_UqCRC2", hue="patient_type", data=df_eda)

# %%
df_control= df_eda.patient_type=='control'

# %%
df_control
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 8181    False
# 8182    False
# 8183    False
# 8184    False
# 8185    False
# Name: patient_type, Length: 8186, dtype: bool

# %% [markdown]
# ## Machine Learning

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# ### Data Preparation with random training/test split

# %%
X = df[['subject_group','Area', 'Perimeter', 'Circularity', 'MED_COX4+4L2','MED_MTCO1', 'MED_NDUFA13', 'MED_NDUFB8', 'MED_OSCP', 'MED_SDHA', 'MED_UqCRC2', 'MED_VDAC1'  ]]
labels = df[['patient_type']]

# %%
train_x, test_x, train_y,test_y = train_test_split(X,labels, train_size=.75)
print("Train X: {} | Train Y: {}".format(train_x.shape,train_y.shape))
print("Test X:  {} | Test Y:  {}".format(test_x.shape,test_y.shape))
# Out:
# Train X: (6139, 12) | Train Y: (6139, 1)
# Test X:  (2047, 12) | Test Y:  (2047, 1)

# %% [markdown]
# ### Binary Class

# %%
clf = RandomForestClassifier(n_jobs=10 , random_state=0)
clf.fit(train_x, train_y)
# Out:
# C:\Users\b6071289\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=10, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
clf.predict(test_x)
# Out:
# array(['patient', 'patient', 'patient', ..., 'patient', 'patient',
#        'patient'], dtype=object)

# %%
print(classification_report(test_y, clf.predict(test_x)))
# Out:
#               precision    recall  f1-score   support
#
#      control       0.95      0.95      0.95       149
#      patient       1.00      1.00      1.00      1898
#
#     accuracy                           0.99      2047
#    macro avg       0.97      0.97      0.97      2047
# weighted avg       0.99      0.99      0.99      2047

# %%
importances = clf.feature_importances_

# %%
std = np.std([tree.feature_importances_ for tree in clf.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(train_x.shape[1]):
    print("%d. feature %d %s (%f)" % (f + 1, indices[f], train_x.columns[f], importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(train_x.shape[1]), importances[indices],
        color="r", yerr=std[indices], align="center")
plt.xticks(range(train_x.shape[1]), indices)
plt.xlim([-1, train_x.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 2 Area (0.707522)
# 2. feature 0 Perimeter (0.101189)
# 3. feature 1 Circularity (0.071379)
# 4. feature 6 MED_COX4+4L2 (0.026750)
# 5. feature 9 MED_MTCO1 (0.023098)
# 6. feature 8 MED_NDUFA13 (0.022957)
# 7. feature 3 MED_NDUFB8 (0.014939)
# 8. feature 5 MED_OSCP (0.014146)
# 9. feature 7 MED_SDHA (0.009226)
# 10. feature 10 MED_UqCRC2 (0.005437)
# 11. feature 4 MED_VDAC1 (0.003359)

# %% [markdown]
# ## Multiclass

# %%
# multi class

X = df[['Area', 'Perimeter', 'Circularity', 'MED_COX4+4L2','MED_MTCO1', 'MED_NDUFA13', 'MED_NDUFB8', 'MED_OSCP', 'MED_SDHA', 'MED_UqCRC2', 'MED_VDAC1'   ]]
labels = df[['subject_group']]

# %%
train_x, test_x, train_y,test_y = train_test_split(X,labels, train_size=.75)
print("Train X: {} | Train Y: {}".format(train_x.shape,train_y.shape))
print("Test X:  {} | Test Y:  {}".format(test_x.shape,test_y.shape))
# Out:
# Train X: (6139, 11) | Train Y: (6139, 1)
# Test X:  (2047, 11) | Test Y:  (2047, 1)

# %%
clf = RandomForestClassifier(n_jobs=10 , random_state=0)
clf.fit(train_x, train_y)

clf.predict(test_x)
# Out:
# C:\Users\b6071289\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# array(['MT-TW', 'MT-TE', 'Control', ..., 'Deletion', 'Deletion', 'MT-TL1'],
#       dtype=object)

# %%
print(classification_report(test_y, clf.predict(test_x)))
# Out:
#               precision    recall  f1-score   support
#
#           CI       0.99      0.96      0.97       141
#      Control       0.94      0.96      0.95       142
#     Deletion       0.87      0.89      0.88       565
#        MT-TE       0.87      0.78      0.82       223
#        MT-TG       0.96      0.83      0.89       147
#       MT-TL1       0.86      0.91      0.89       683
#        MT-TW       0.87      0.81      0.84       146
#
#     accuracy                           0.89      2047
#    macro avg       0.91      0.88      0.89      2047
# weighted avg       0.89      0.89      0.89      2047

# %%
importances = clf.feature_importances_

# %%
importances
# Out:
# array([0.12411425, 0.09040961, 0.17051384, 0.12864325, 0.05094386,
#        0.04344271, 0.04817272, 0.09655792, 0.09428623, 0.10730874,
#        0.04560688])

# %%
std = np.std([tree.feature_importances_ for tree in clf.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(X.shape[1]):
    print("%d. feature %d %s (%f)" % (f + 1, indices[f], X.columns[f], importances[indices[f]]))

# Plot the impurity-based feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(X.shape[1]), importances[indices],
        color="r", yerr=std[indices], align="center")
plt.xticks(range(X.shape[1]), indices)
plt.xlim([-1, X.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 2 Area (0.170514)
# 2. feature 3 Perimeter (0.128643)
# 3. feature 0 Circularity (0.124114)
# 4. feature 9 MED_COX4+4L2 (0.107309)
# 5. feature 7 MED_MTCO1 (0.096558)
# 6. feature 8 MED_NDUFA13 (0.094286)
# 7. feature 1 MED_NDUFB8 (0.090410)
# 8. feature 4 MED_OSCP (0.050944)
# 9. feature 6 MED_SDHA (0.048173)
# 10. feature 10 MED_UqCRC2 (0.045607)
# 11. feature 5 MED_VDAC1 (0.043443)

# %% [markdown]
# ### Data preparation with 7 individuals for training and 4 for testing

# %%
#dfx = df[['patient_type','subject_group','patient_id','Area', 'AspectRatio','xCoord', 'yCoord', 'Perimeter', 'Circularity', 'LOG_COX4+4L2','LOG_MTCO1', 'LOG_NDUFA13', 'LOG_NDUFB8', 'LOG_OSCP', 'LOG_SDHA', 'LOG_UqCRC2', 'LOG_VDAC1'  ]]
dfx = df.drop(['colour','cell_id'],1)

# %%
dfx.groupby(['patient_id','subject_group']).sum()
# Out:
# P08        MT-TG           8995.515510   50238.422370    2832.772121
# P09        MT-TE           7628.210942   66917.734405    4490.517343
# P10        MT-TW          15769.707464   48060.656097    6579.410061
#
#                            THETA_UqCRC2
# patient_id subject_group
# C01        Control          9131.490884
# C02        Control         17156.612951
# C03        Control          9186.720300
# P01        CI              27052.674297
# P02        CI              18625.130504
# P03        Deletion        84674.856034
# P04        Deletion        65202.391998
# P05        MT-TL1         130289.885405
# P07        MT-TL1          55016.884014
# P08        MT-TG           37752.520333
# P09        MT-TE           56871.942742
# P10        MT-TW           40508.934024

# %%
X_train = dfx[dfx.patient_id != "P02"]
X_train = X_train[X_train.patient_id != "P04"]
X_train = X_train[X_train.patient_id != "P07"]
X_train = X_train[X_train.patient_id != "C02"]
X_train
# Out:
#      patient_type subject_group patient_id    Area  AspectRatio   COX4+4L2  \
# 0         control       Control        C01   879.0     0.448980   4.926230
# 1         control       Control        C01  2556.0     0.876923   9.064356
# 2         control       Control        C01  6432.0     0.800000   7.408696
# 3         control       Control        C01  3072.0     1.157143   8.756881
# 4         control       Control        C01  8734.5     1.595238   5.994460
# ...           ...           ...        ...     ...          ...        ...
# 8181      patient         MT-TW        P10  1858.0     2.000000   8.157025
# 8182      patient         MT-TW        P10  3970.5     1.451613   8.354244
# 8183      patient         MT-TW        P10  1458.0     2.900000  13.741228
# 8184      patient         MT-TW        P10  1276.5     3.133333  15.060748
# 8185      patient         MT-TW        P10  1339.5     1.555556   7.575000
#
#       Circularity  LOG_COX4+4L2  LOG_MTCO1  LOG_NDUFA13  LOG_NDUFB8  \
# 0        0.667624      3.528312   1.512562     1.718303    1.926028
# 1        0.662271      6.656274   1.763175     2.777602    2.671580
# 2        0.484423      5.569829   1.652074     2.207175    2.160935
# 3        0.608063      7.275473   1.843152     2.923391    2.566386
# 4        0.705084      4.253457   1.421162     1.760127    1.769816
# ...           ...           ...        ...          ...         ...
# 8181     0.240837      6.455170   1.407893     1.904649    1.519806
# 8182     0.409971      7.325609   1.150830     1.477179    1.191700
# 8183     0.198452     11.432586   1.307792     1.628173    1.312751
# 8184     0.228461     13.320255   1.817468     3.064791    2.606018
# 8185     0.240358      6.022850   1.099100     1.324772    1.206204
#
#        LOG_OSCP   LOG_SDHA  LOG_UqCRC2  LOG_VDAC1  MED_COX4+4L2  MED_MTCO1  \
# 0      2.092291   2.498110    2.793981   1.574617           4.0        1.0
# 1      2.926415   4.195481    4.720006   1.753394           7.0        2.0
# 2      2.409333   3.632043    3.797937   1.552955           6.0        2.0
# 3      2.976915   4.496332    4.825183   1.750554           8.0        2.0
# 4      2.003908   2.789748    2.704791   1.469509           4.0        1.0
# ...         ...        ...         ...        ...           ...        ...
# 8181  10.240695  13.661039   10.582099   2.976675           7.0        1.0
# 8182  21.188446  44.385100   14.004130   5.544963           8.0        1.0
# 8183  40.187626  63.152782   28.195734   9.497522          12.0        1.0
# 8184   4.084146   5.848844    8.787500   2.405839          14.0        2.0
# 8185  14.693705  33.566143    9.559546   4.394516           6.0        1.0
#
# P08        MT-TG            33462.122074   1539.336192  17839.953048
# P09        MT-TE            67381.314270   2914.680869  38170.816838
# P10        MT-TW            31704.045077   2525.999074  13043.646549
#
#                           RADIUS_NDUFA13  THETA_NDUFA13  RADIUS_NDUFB8  \
# patient_id subject_group
# C01        Control            402.146690    7857.356865     426.443762
# C03        Control            670.916161    7802.233831     659.129638
# P01        CI                 929.539962   10895.067088     882.670751
# P03        Deletion          3175.141142   72682.084866    3117.323678
# P05        MT-TL1            5013.016919   93913.342984    4686.893467
# P08        MT-TG             1671.161271   22229.858564    1593.299153
# P09        MT-TE             3365.992158   43203.662010    3221.566770
# P10        MT-TW             2659.086189   15633.031635    2589.365335
#
#                           THETA_NDUFB8  RADIUS_OSCP     THETA_OSCP  \
# patient_id subject_group
# C01        Control         8196.736290   445.532372    8445.929550
# C03        Control         7795.830445   792.604385    8449.260761
# P01        CI              9117.537440  3640.314102   25835.583695
# P03        Deletion       71611.175982  3139.078493   72559.701625
# P05        MT-TL1         88145.963499  6764.567119  114297.045826
# P08        MT-TG          19848.845635  7099.160558   47637.530161
# P09        MT-TE          41133.741981  4561.317432   56023.605906
# P10        MT-TW          14192.519394  7553.846164   41651.159987
#
#                            RADIUS_SDHA     THETA_SDHA  RADIUS_UqCRC2  \
# patient_id subject_group
# C01        Control          520.668898    9187.147873     511.763636
# C03        Control         1085.465106    9325.043113    1035.718798
# P01        CI              5756.126504   27511.754952    5020.459754
# P03        Deletion        4585.509477   88639.459848    4110.012399
# P05        MT-TL1         10051.697585  130680.474217    9366.301898
# P08        MT-TG           8995.515510   50238.422370    2832.772121
# P09        MT-TE           7628.210942   66917.734405    4490.517343
# P10        MT-TW          15769.707464   48060.656097    6579.410061
#
#                            THETA_UqCRC2
# patient_id subject_group
# C01        Control          9131.490884
# C03        Control          9186.720300
# P01        CI              27052.674297
# P03        Deletion        84674.856034
# P05        MT-TL1         130289.885405
# P08        MT-TG           37752.520333
# P09        MT-TE           56871.942742
# P10        MT-TW           40508.934024

# %%
X_test = dfx[(dfx.patient_id == "P02") | (dfx.patient_id == "P04") | (dfx.patient_id == "P07") | (dfx.patient_id == "C02") ]
X_test
# Out:
#      patient_type subject_group patient_id    Area  AspectRatio   COX4+4L2  \
# 148       control       Control        C02  2042.0     1.142857   4.187500
# 149       control       Control        C02  7484.5     1.028037   3.857567
# 150       control       Control        C02  2209.5     1.339623   7.145078
# 151       control       Control        C02  1914.5     1.014085   4.882629
# 152       control       Control        C02  3116.0     1.509091   5.523364
# ...           ...           ...        ...     ...          ...        ...
# 6005      patient        MT-TL1        P07  3126.0     0.491228  17.205263
# 6006      patient        MT-TL1        P07  2509.5     0.851351  18.671141
# 6007      patient        MT-TL1        P07   949.0     1.096154  26.759494
# 6008      patient        MT-TL1        P07  1456.5     1.200000   8.957447
# 6009      patient        MT-TL1        P07  2372.5     0.439560  13.642857
#
#       Circularity  LOG_COX4+4L2  LOG_MTCO1  LOG_NDUFA13  LOG_NDUFB8  \
# 148      0.710195      3.564187   1.347232     1.688322    1.639983
train_x = X_train.drop(['patient_id','patient_type','subject_group', 'AspectRatio','xCoord','yCoord', 'RADIUS_COX4+4L2','THETA_COX4+4L2','RADIUS_MTCO1','THETA_MTCO1','RADIUS_NDUFA13','THETA_NDUFA13','RADIUS_NDUFB8','THETA_NDUFB8','RADIUS_OSCP','THETA_OSCP','RADIUS_SDHA','THETA_SDHA','RADIUS_UqCRC2','THETA_UqCRC2' ,  'LOG_COX4+4L2','LOG_MTCO1', 'LOG_NDUFA13', 'LOG_NDUFB8', 'LOG_OSCP', 'LOG_SDHA', 'LOG_UqCRC2', 'LOG_VDAC1','MTCO1', 'COX4+4L2', 'NDUFA13', 'NDUFB8', 'OSCP', 'SDHA', 'UqCRC2', 'VDAC1'],1)
train_y = X_train[['subject_group']]

#test_x =X_test[['Area', 'Perimeter', 'Circularity', 'LOG_COX4+4L2','LOG_MTCO1', 'LOG_NDUFA13', 'LOG_NDUFB8', 'LOG_OSCP', 'LOG_SDHA', 'LOG_UqCRC2', 'LOG_VDAC1'  ]]
test_x =X_test.drop(['patient_id','patient_type','subject_group', 'AspectRatio','xCoord','yCoord', 'RADIUS_COX4+4L2','THETA_COX4+4L2','RADIUS_MTCO1','THETA_MTCO1','RADIUS_NDUFA13','THETA_NDUFA13','RADIUS_NDUFB8','THETA_NDUFB8','RADIUS_OSCP','THETA_OSCP','RADIUS_SDHA','THETA_SDHA','RADIUS_UqCRC2','THETA_UqCRC2', 'LOG_COX4+4L2','LOG_MTCO1', 'LOG_NDUFA13', 'LOG_NDUFB8', 'LOG_OSCP', 'LOG_SDHA', 'LOG_UqCRC2', 'LOG_VDAC1' ,'COX4+4L2','MTCO1', 'NDUFA13', 'NDUFB8', 'OSCP', 'SDHA', 'UqCRC2', 'VDAC1'],1)
test_y =X_test[['subject_group']]

# %% [markdown]
# ## Classifiers

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
train_x = train_x[train_x.subject_group == "Control"]
test_x = test_x[test_x.subject_group == "Control"]

train_LX = train_x [['MED_VDAC1']]
train_LY = train_x [['MED_COX4+4L2']]

test_LX = test_x [['MED_VDAC1']]
test_LY = test_x [['MED_COX4+4L2']]

reg = LinearRegression().fit(train_LX, train_LY)



test_pred = reg.predict(test_LX)
train_pred = reg.predict(train_LX)

# Plot outputs
plt.scatter(test_LX, test_LY,  color='black')
plt.plot(test_LX, test_pred, color='blue', linewidth=3)

#plt.scatter(train_LX, train_LY,  color='black')
#plt.plot(train_LX, train_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()

# %% [markdown]
# ### Random Forest

# %%
clf = RandomForestClassifier(n_jobs=10 , random_state=0)
clf.fit(train_x, train_y)
# Out:
# C:\Users\b6071289\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=10, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
clf.predict(test_x)
# Out:
# array(['Control', 'Control', 'Control', ..., 'CI', 'MT-TL1', 'CI'],
#       dtype=object)

# %%
print(classification_report(test_y, clf.predict(test_x)))
# Out:
#               precision    recall  f1-score   support
#
#           CI       0.50      0.97      0.66       232
#      Control       0.98      0.85      0.91       289
#     Deletion       0.08      0.01      0.02       879
#        MT-TE       0.00      0.00      0.00         0
#        MT-TG       0.00      0.00      0.00         0
#       MT-TL1       0.12      0.04      0.06       755
#        MT-TW       0.00      0.00      0.00         0
#
#     accuracy                           0.24      2155
#    macro avg       0.24      0.27      0.24      2155
# weighted avg       0.26      0.24      0.22      2155
# C:\Users\b6071289\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
importances = clf.feature_importances_

# %%
std = np.std([tree.feature_importances_ for tree in clf.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(train_x.shape[1]):
    print("%d. feature %d %s (%f)" % (f + 1, indices[f], train_x.columns[f], importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(train_x.shape[1]), importances[indices],
        color="r", yerr=std[indices], align="center")
plt.xticks(range(train_x.shape[1]), indices)
plt.xlim([-1, train_x.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 0 Area (0.165123)
# 2. feature 2 Circularity (0.127279)
# 3. feature 8 MED_COX4+4L2 (0.123038)
# 4. feature 1 MED_MTCO1 (0.110632)
# 5. feature 7 MED_NDUFA13 (0.106969)
# 6. feature 10 MED_NDUFB8 (0.102998)
# 7. feature 6 MED_OSCP (0.102100)
# 8. feature 9 MED_SDHA (0.048959)
# 9. feature 5 MED_UqCRC2 (0.046715)
# 10. feature 3 MED_VDAC1 (0.034272)
# 11. feature 4 Perimeter (0.031914)

# %% [markdown]
# ## XGBoost

# %%
import xgboost as xgb

# %%
dfxg = df.drop(['colour','cell_id'],1)

X_train = dfxg[(dfxg.patient_id != "P02") & (dfxg.patient_id != "P04") & (dfxg.patient_id != "P07") & (dfxg.patient_id != "C02") ]
X_train
# Out:
#      patient_type subject_group patient_id    Area  AspectRatio   COX4+4L2  \
# 0         control       Control        C01   879.0     0.448980   4.926230
# 1         control       Control        C01  2556.0     0.876923   9.064356
# 2         control       Control        C01  6432.0     0.800000   7.408696
# 3         control       Control        C01  3072.0     1.157143   8.756881
# 4         control       Control        C01  8734.5     1.595238   5.994460
# ...           ...           ...        ...     ...          ...        ...
# 8181      patient         MT-TW        P10  1858.0     2.000000   8.157025
# 8182      patient         MT-TW        P10  3970.5     1.451613   8.354244
# 8183      patient         MT-TW        P10  1458.0     2.900000  13.741228
# 8184      patient         MT-TW        P10  1276.5     3.133333  15.060748
# 8185      patient         MT-TW        P10  1339.5     1.555556   7.575000
#
#       Circularity  LOG_COX4+4L2  LOG_MTCO1  LOG_NDUFA13  LOG_NDUFB8  \
# 0        0.667624      3.528312   1.512562     1.718303    1.926028
# 1        0.662271      6.656274   1.763175     2.777602    2.671580
# 2        0.484423      5.569829   1.652074     2.207175    2.160935
# 3        0.608063      7.275473   1.843152     2.923391    2.566386
# 4        0.705084      4.253457   1.421162     1.760127    1.769816
# ...           ...           ...        ...          ...         ...
# 8181     0.240837      6.455170   1.407893     1.904649    1.519806
# 8182     0.409971      7.325609   1.150830     1.477179    1.191700
# 8183     0.198452     11.432586   1.307792     1.628173    1.312751
# 8184     0.228461     13.320255   1.817468     3.064791    2.606018
# 8185     0.240358      6.022850   1.099100     1.324772    1.206204
#
#        LOG_OSCP   LOG_SDHA  LOG_UqCRC2  LOG_VDAC1  MED_COX4+4L2  MED_MTCO1  \
train_x = X_train.drop(['patient_id','patient_type','subject_group', 'AspectRatio','xCoord','yCoord', 'RADIUS_COX4+4L2','THETA_COX4+4L2','RADIUS_MTCO1','THETA_MTCO1','RADIUS_NDUFA13','THETA_NDUFA13','RADIUS_NDUFB8','THETA_NDUFB8','RADIUS_OSCP','THETA_OSCP','RADIUS_SDHA','THETA_SDHA','RADIUS_UqCRC2','THETA_UqCRC2' ,  'LOG_COX4+4L2','LOG_MTCO1', 'LOG_NDUFA13', 'LOG_NDUFB8', 'LOG_OSCP', 'LOG_SDHA', 'LOG_UqCRC2', 'LOG_VDAC1','MTCO1', 'COX4+4L2', 'NDUFA13', 'NDUFB8', 'OSCP', 'SDHA', 'UqCRC2', 'VDAC1'],1)
train_y = X_train[['subject_group']]

#test_x =X_test[['Area', 'Perimeter', 'Circularity', 'LOG_COX4+4L2','LOG_MTCO1', 'LOG_NDUFA13', 'LOG_NDUFB8', 'LOG_OSCP', 'LOG_SDHA', 'LOG_UqCRC2', 'LOG_VDAC1'  ]]
test_x =X_test.drop(['patient_id','patient_type','subject_group', 'AspectRatio','xCoord','yCoord', 'RADIUS_COX4+4L2','THETA_COX4+4L2','RADIUS_MTCO1','THETA_MTCO1','RADIUS_NDUFA13','THETA_NDUFA13','RADIUS_NDUFB8','THETA_NDUFB8','RADIUS_OSCP','THETA_OSCP','RADIUS_SDHA','THETA_SDHA','RADIUS_UqCRC2','THETA_UqCRC2', 'LOG_COX4+4L2','LOG_MTCO1', 'LOG_NDUFA13', 'LOG_NDUFB8', 'LOG_OSCP', 'LOG_SDHA', 'LOG_UqCRC2', 'LOG_VDAC1' ,'COX4+4L2','MTCO1', 'NDUFA13', 'NDUFB8', 'OSCP', 'SDHA', 'UqCRC2', 'VDAC1'],1)
test_y =X_test[['subject_group']]

# %%
from sklearn.model_selection import GridSearchCV

clf = xgb.XGBClassifier()
parameters = {
     "eta"    : [0.05, 0.10, 0.15, 0.20, 0.25, 0.30 ] ,
     "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12, 15],
     "min_child_weight" : [ 1, 3, 5, 7 ],
     "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
     "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ]
     }

grid = GridSearchCV(clf,
                    parameters, n_jobs=4,
                    scoring="neg_log_loss",
                    cv=3)

grid.fit(train_x, train_y)
# Out:
# C:\Users\b6071289\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\b6071289\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(cv=3, error_score=nan,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, gamma=None,
#                                      gpu_id=None, importance_type='gain',
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estim...
#                                      subsample=None, tree_method=None,
#                                      validate_parameters=False,
#                                      verbosity=None),
#              iid='deprecated', n_jobs=4,
#              param_grid={'colsample_bytree': [0.3, 0.4, 0.5, 0.7],
#                          'eta': [0.05, 0.1, 0.15, 0.2, 0.25, 0.3],
#                          'gamma': [0.0, 0.1, 0.2, 0.3, 0.4],
#                          'max_depth': [3, 4, 5, 6, 8, 10, 12, 15],
#                          'min_child_weight': [1, 3, 5, 7]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='neg_log_loss', verbose=0)

# %%
grid.predict(test_x)
# Out:
# array(['Control', 'Control', 'Control', ..., 'CI', 'MT-TL1', 'CI'],
#       dtype=object)

# %%
print(classification_report(test_y, grid.predict(test_x)))
# Out:
#               precision    recall  f1-score   support
#
#           CI       0.53      0.97      0.69       232
#      Control       0.98      0.80      0.88       289
#     Deletion       0.04      0.01      0.01       879
#        MT-TE       0.00      0.00      0.00         0
#        MT-TG       0.00      0.00      0.00         0
#       MT-TL1       0.17      0.05      0.08       755
#        MT-TW       0.00      0.00      0.00         0
#
#     accuracy                           0.23      2155
#    macro avg       0.25      0.26      0.24      2155
# weighted avg       0.27      0.23      0.23      2155
# C:\Users\b6071289\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(grid.best_estimator_.feature_importances_)
# Out:
# [0.08989233 0.05208931 0.08930474 0.08719284 0.088425   0.0929186
#  0.15453173 0.0886588  0.0914351  0.08704769 0.07850391]

# %%
importances = grid.best_estimator_.feature_importances_

# %%
#std = np.std([grid.best_estimator_.feature_importances_ for tree in grid.best_estimator_],
#             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(train_x.shape[1]):
    print("%d. feature %d %s (%f)" % (f + 1, indices[f], train_x.columns[f], importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(train_x.shape[1]), importances[indices],
        color="r", align="center")
plt.xticks(range(train_x.shape[1]), indices)
plt.xlim([-1, train_x.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 6 Area (0.154532)
# 2. feature 5 Circularity (0.092919)
# 3. feature 8 MED_COX4+4L2 (0.091435)
# 4. feature 0 MED_MTCO1 (0.089892)
# 5. feature 2 MED_NDUFA13 (0.089305)
# 6. feature 7 MED_NDUFB8 (0.088659)
# 7. feature 4 MED_OSCP (0.088425)
# 8. feature 3 MED_SDHA (0.087193)
# 9. feature 9 MED_UqCRC2 (0.087048)
# 10. feature 10 MED_VDAC1 (0.078504)
# 11. feature 1 Perimeter (0.052089)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
dfxg = df.drop(['colour','cell_id'],1)

X_train = dfxg[(dfxg.patient_id != "P02") & (dfxg.patient_id != "P04") & (dfxg.patient_id != "P07") & (dfxg.patient_id != "C02") ]
X_train
# Out:
#      patient_type subject_group patient_id    Area  AspectRatio   COX4+4L2  \
# 0         control       Control        C01   879.0     0.448980   4.926230
# 1         control       Control        C01  2556.0     0.876923   9.064356
# 2         control       Control        C01  6432.0     0.800000   7.408696
# 3         control       Control        C01  3072.0     1.157143   8.756881
# 4         control       Control        C01  8734.5     1.595238   5.994460
# ...           ...           ...        ...     ...          ...        ...
# 8181      patient         MT-TW        P10  1858.0     2.000000   8.157025
# 8182      patient         MT-TW        P10  3970.5     1.451613   8.354244
# 8183      patient         MT-TW        P10  1458.0     2.900000  13.741228
# 8184      patient         MT-TW        P10  1276.5     3.133333  15.060748
# 8185      patient         MT-TW        P10  1339.5     1.555556   7.575000
#
#       Circularity  LOG_COX4+4L2  LOG_MTCO1  LOG_NDUFA13  LOG_NDUFB8  \
# 0        0.667624      3.528312   1.512562     1.718303    1.926028
# 1        0.662271      6.656274   1.763175     2.777602    2.671580
# 2        0.484423      5.569829   1.652074     2.207175    2.160935
# 3        0.608063      7.275473   1.843152     2.923391    2.566386
# 4        0.705084      4.253457   1.421162     1.760127    1.769816
train_x = X_train.drop(['patient_id','patient_type','subject_group', 'AspectRatio','xCoord','yCoord', 'RADIUS_COX4+4L2','THETA_COX4+4L2','RADIUS_MTCO1','THETA_MTCO1','RADIUS_NDUFA13','THETA_NDUFA13','RADIUS_NDUFB8','THETA_NDUFB8','RADIUS_OSCP','THETA_OSCP','RADIUS_SDHA','THETA_SDHA','RADIUS_UqCRC2','THETA_UqCRC2' ,  'LOG_COX4+4L2','LOG_MTCO1', 'LOG_NDUFA13', 'LOG_NDUFB8', 'LOG_OSCP', 'LOG_SDHA', 'LOG_UqCRC2', 'LOG_VDAC1','MTCO1', 'COX4+4L2', 'NDUFA13', 'NDUFB8', 'OSCP', 'SDHA', 'UqCRC2', 'VDAC1'],1)
train_y = X_train[['subject_group']]

#test_x =X_test[['Area', 'Perimeter', 'Circularity', 'LOG_COX4+4L2','LOG_MTCO1', 'LOG_NDUFA13', 'LOG_NDUFB8', 'LOG_OSCP', 'LOG_SDHA', 'LOG_UqCRC2', 'LOG_VDAC1'  ]]
test_x =X_test.drop(['patient_id','patient_type','subject_group', 'AspectRatio','xCoord','yCoord', 'RADIUS_COX4+4L2','THETA_COX4+4L2','RADIUS_MTCO1','THETA_MTCO1','RADIUS_NDUFA13','THETA_NDUFA13','RADIUS_NDUFB8','THETA_NDUFB8','RADIUS_OSCP','THETA_OSCP','RADIUS_SDHA','THETA_SDHA','RADIUS_UqCRC2','THETA_UqCRC2', 'LOG_COX4+4L2','LOG_MTCO1', 'LOG_NDUFA13', 'LOG_NDUFB8', 'LOG_OSCP', 'LOG_SDHA', 'LOG_UqCRC2', 'LOG_VDAC1' ,'COX4+4L2','MTCO1', 'NDUFA13', 'NDUFB8', 'OSCP', 'SDHA', 'UqCRC2', 'VDAC1'],1)
test_y =X_test[['subject_group']]

# %%
clf = LogisticRegression(random_state=0).fit(train_x, train_y)
# Out:
# C:\Users\b6071289\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\b6071289\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
print(classification_report(test_y, clf.predict(test_x)))
# Out:
#               precision    recall  f1-score   support
#
#           CI       0.67      0.63      0.65       232
#      Control       0.82      0.64      0.72       289
#     Deletion       0.59      0.32      0.42       879
#        MT-TE       0.00      0.00      0.00         0
#        MT-TG       0.00      0.00      0.00         0
#       MT-TL1       0.12      0.08      0.10       755
#        MT-TW       0.00      0.00      0.00         0
#
#     accuracy                           0.32      2155
#    macro avg       0.31      0.24      0.27      2155
# weighted avg       0.46      0.32      0.37      2155
# C:\Users\b6071289\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
from matplotlib import pyplot

importance = clf.coef_[0]
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: -0.00216
# Feature: 1, Score: -0.00204
# Feature: 2, Score: 0.11349
# Feature: 3, Score: 0.00944
# Feature: 4, Score: -0.01571
# Feature: 5, Score: -0.01456
# Feature: 6, Score: 0.02355
# Feature: 7, Score: 0.02865
# Feature: 8, Score: 0.05651
# Feature: 9, Score: -0.00569
# Feature: 10, Score: 0.01883

# %%
indices = np.argsort(importance)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(train_x.shape[1]):
    print("%d. feature %d %s (%f)" % (f + 1, indices[f], train_x.columns[f], importance[indices[f]]))

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(train_x.shape[1]), importance[indices],
        color="r", yerr=std[indices], align="center")
plt.xticks(range(train_x.shape[1]), indices)
plt.xlim([-1, train_x.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 2 Area (0.113492)
# 2. feature 8 Circularity (0.056507)
# 3. feature 7 MED_COX4+4L2 (0.028655)
# 4. feature 6 MED_MTCO1 (0.023554)
# 5. feature 10 MED_NDUFA13 (0.018825)
# 6. feature 3 MED_NDUFB8 (0.009436)
# 7. feature 1 MED_OSCP (-0.002037)
# 8. feature 0 MED_SDHA (-0.002158)
# 9. feature 9 MED_UqCRC2 (-0.005688)
# 10. feature 5 MED_VDAC1 (-0.014557)
# 11. feature 4 Perimeter (-0.015711)

# %% [markdown]
# ## Predicting Patient IDs

# %%
X = df[['Area', 'Perimeter', 'Circularity', 'MED_COX4+4L2','MED_MTCO1', 'MED_NDUFA13', 'MED_NDUFB8', 'MED_OSCP', 'MED_SDHA', 'MED_UqCRC2', 'MED_VDAC1'  ]]
labels = df[['patient_id']]

# %%
train_x, test_x, train_y,test_y = train_test_split(X,labels, train_size=.75)
print("Train X: {} | Train Y: {}".format(train_x.shape,train_y.shape))
print("Test X:  {} | Test Y:  {}".format(test_x.shape,test_y.shape))
# Out:
# Train X: (6139, 11) | Train Y: (6139, 1)
# Test X:  (2047, 11) | Test Y:  (2047, 1)

# %%
clf = RandomForestClassifier(n_jobs=10 , random_state=0)
clf.fit(train_x, train_y)

clf.predict(test_x)
# Out:
# C:\Users\b6071289\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# array(['P09', 'P01', 'P07', ..., 'P02', 'P10', 'P03'], dtype=object)

# %%
print(classification_report(test_y, clf.predict(test_x)))
# Out:
#               precision    recall  f1-score   support
#
#          C01       0.70      0.76      0.73        37
#          C02       0.89      0.92      0.91        90
#          C03       0.89      0.92      0.91        26
#          P01       0.95      0.92      0.93        84
#          P02       0.98      0.90      0.93        48
#          P03       0.83      0.86      0.85       338
#          P04       0.92      0.93      0.92       224
#          P05       0.86      0.93      0.90       480
#          P07       0.85      0.89      0.87       193
#          P08       0.95      0.85      0.90       148
#          P09       0.85      0.77      0.81       238
#          P10       0.90      0.73      0.80       141
#
#     accuracy                           0.87      2047
#    macro avg       0.88      0.87      0.87      2047
# weighted avg       0.87      0.87      0.87      2047

# %%
importances = clf.feature_importances_

# %%
std = np.std([tree.feature_importances_ for tree in clf.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(X.shape[1]):
    print("%d. feature %d %s (%f)" % (f + 1, indices[f], X.columns[f], importances[indices[f]]))

# Plot the impurity-based feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(X.shape[1]), importances[indices],
        color="r", yerr=std[indices], align="center")
plt.xticks(range(X.shape[1]), indices)
plt.xlim([-1, X.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 0 Area (0.149669)
# 2. feature 2 Perimeter (0.132963)
# 3. feature 1 Circularity (0.118002)
# 4. feature 3 MED_COX4+4L2 (0.117533)
# 5. feature 9 MED_MTCO1 (0.104759)
# 6. feature 8 MED_NDUFA13 (0.102242)
# 7. feature 7 MED_NDUFB8 (0.082431)
# 8. feature 6 MED_OSCP (0.052624)
# 9. feature 4 MED_SDHA (0.048650)
# 10. feature 5 MED_UqCRC2 (0.046759)
# 11. feature 10 MED_VDAC1 (0.044367)

# %%
ax = sns.scatterplot(x="Area", y="patient_id", hue="patient_type", palette='muted',legend=False,data=df_eda)

# %%
ax = sns.scatterplot(x="Perimeter", y="patient_id", hue="patient_type", palette='muted',legend=False,data=df_eda)

# %%
ax = sns.scatterplot(x="Circularity", y="patient_id", hue="patient_type", palette='muted',legend=False,data=df_eda)

# %%
ax = sns.scatterplot(x="Area", y="patient_id", hue="subject_group", palette='muted',legend=False,data=df_eda)

# %%
ax = sns.scatterplot(x="Perimeter", y="patient_id", hue="subject_group", palette='muted',legend=False,data=df_eda)

# %%
ax = sns.scatterplot(x="Circularity", y="patient_id", hue="subject_group", palette='muted',legend=False,data=df_eda)

# %% [markdown]
# ## Clustering based ML

# %%
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
from time import time
from mpl_toolkits.mplot3d import Axes3D

df_cml = df

X = df_cml[['Area', 'AspectRatio', 'Perimeter', 'Circularity', 'LOG_COX4+4L2','LOG_MTCO1', 'LOG_NDUFA13', 'LOG_NDUFB8', 'LOG_OSCP', 'LOG_SDHA', 'LOG_UqCRC2', 'LOG_VDAC1'  ]]
labels = df_cml[['patient_type']]

labels.patient_type = labels.patient_type.astype("category")
labels.patient_type = labels.patient_type.cat.codes
labels.patient_type = labels.patient_type.astype("int")

cls = KMeans(n_clusters = 2)
cls.fit(X)
# Out:
# C:\Users\b6071289\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
color_theme = np.array(['darkgray', 'lightsalmon','powderblue'])

plt.subplot(1,2,1)

plt.scatter(x=X.LOG_VDAC1, y=X.LOG_NDUFA13 , c=color_theme[labels.patient_type], s=50 )
plt.title('Ground Truth')

plt.subplot(1,2,2)
plt.scatter(x=X.LOG_VDAC1, y=X.LOG_NDUFA13 , c=color_theme[cls.labels_], s=50 )
plt.title('Predictions')
# Out:
# Text(0.5, 1.0, 'Predictions')

# %%
sample_size = len(X)
def bench_k_means(estimator, name, data):
    t0 = time()
    estimator.fit(data)
    print('%-9s\t%.2fs\t%i\t%.3f\t%.3f\t%.3f\t%.3f\t%.3f\t%.3f'
          % (name, (time() - t0), estimator.inertia_,
             metrics.homogeneity_score(labels.patient_type, estimator.labels_),
             metrics.completeness_score(labels.patient_type, estimator.labels_),
             metrics.v_measure_score(labels.patient_type, estimator.labels_),
             metrics.adjusted_rand_score(labels.patient_type, estimator.labels_),
             metrics.adjusted_mutual_info_score(labels.patient_type,  estimator.labels_),
             metrics.silhouette_score(data, estimator.labels_,
                                      metric='euclidean',
                                      sample_size=sample_size)))

bench_k_means(KMeans(init='k-means++', n_clusters=2, n_init=10),
              name="k-means++", data=X)

bench_k_means(KMeans(init='random', n_clusters=2, n_init=10),
              name="random", data=X)
# Out:
# k-means++	0.13s	18542082309	0.011	0.004	0.006	0.023	0.006	0.454
# random   	0.09s	18542082309	0.011	0.004	0.006	0.023	0.006	0.454

# %% [markdown]
# ### Feature Engineering

# %%
X = df_cml[['Area', 'AspectRatio', 'Perimeter', 'Circularity', 'LOG_COX4+4L2','LOG_MTCO1', 'LOG_NDUFA13', 'LOG_NDUFB8', 'LOG_OSCP', 'LOG_SDHA', 'LOG_UqCRC2', 'LOG_VDAC1'  ]]
labels = df_cml[['patient_type']]

labels.patient_type = labels.patient_type.astype("category")
labels.patient_type = labels.patient_type.cat.codes
labels.patient_type = labels.patient_type.astype("int")

cls = KMeans(n_clusters = 2)
cls.fit(X)
# Out:
# C:\Users\b6071289\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
color_theme = np.array(['darkgray', 'lightsalmon','powderblue'])

plt.subplot(1,2,1)

plt.scatter(x=X.LOG_VDAC1, y=X.LOG_NDUFA13 , c=color_theme[labels.patient_type], s=50 )
plt.title('Ground Truth')

plt.subplot(1,2,2)
plt.scatter(x=X.LOG_VDAC1, y=X.LOG_NDUFA13 , c=color_theme[cls.labels_], s=50 )
plt.title('Predictions')
# Out:
# Text(0.5, 1.0, 'Predictions')

# %%
print(classification_report(labels.patient_type,cls.labels_))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.06      0.52      0.10       568
#            1       0.90      0.33      0.49      7618
#
#     accuracy                           0.35      8186
#    macro avg       0.48      0.43      0.29      8186
# weighted avg       0.84      0.35      0.46      8186

# %% [markdown]
# ### Using Polar dimensions

# %%
X = df_cml[['Area', 'AspectRatio', 'Perimeter', 'Circularity', 'THETA_COX4+4L2','THETA_MTCO1', 'THETA_NDUFA13', 'THETA_NDUFB8', 'THETA_OSCP', 'THETA_SDHA', 'THETA_UqCRC2'  ]]
labels = df_cml[['patient_type']]

labels.patient_type = labels.patient_type.astype("category")
labels.patient_type = labels.patient_type.cat.codes
labels.patient_type = labels.patient_type.astype("int")

cls = KMeans(n_clusters = 2)
cls.fit(X)
# Out:
# C:\Users\b6071289\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
print(classification_report(labels.patient_type,cls.labels_))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.05      0.52      0.10       568
#            1       0.90      0.33      0.49      7618
#
#     accuracy                           0.35      8186
#    macro avg       0.48      0.43      0.29      8186
# weighted avg       0.84      0.35      0.46      8186

# %% [markdown]
# ### PCA

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=6)

pca.fit(X)

X_pca = pca.transform(X)

# %%
labels = df_cml[['patient_type']]

labels.patient_type = labels.patient_type.astype("category")

labels.patient_type = labels.patient_type.cat.codes

labels.patient_type = labels.patient_type.astype("int")


cls = KMeans(n_clusters = 2)
cls.fit(X_pca)
# Out:
# C:\Users\b6071289\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
print(classification_report(labels.patient_type,cls.labels_))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.10      0.48      0.16       568
#            1       0.95      0.67      0.78      7618
#
#     accuracy                           0.65      8186
#    macro avg       0.52      0.57      0.47      8186
# weighted avg       0.89      0.65      0.74      8186

# %% [markdown]
# ### using subject_group

# %%
labels = df_cml[['subject_group']]

labels.subject_group = labels.subject_group.astype("category")

labels.subject_group = labels.subject_group.cat.codes

labels.subject_group = labels.subject_group.astype("int")

cls = KMeans(n_clusters = 7)
cls.fit(X_pca)
# Out:
# C:\Users\b6071289\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=7, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
print(classification_report(labels.subject_group,cls.labels_))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.01      0.05      0.02       569
#            1       0.11      0.32      0.16       568
#            2       0.21      0.12      0.15      2240
#            3       0.03      0.00      0.00       946
#            4       0.05      0.02      0.03       628
#            5       0.19      0.06      0.09      2633
#            6       0.05      0.14      0.07       602
#
#     accuracy                           0.09      8186
#    macro avg       0.09      0.10      0.08      8186
# weighted avg       0.14      0.09      0.09      8186

# %% [markdown]
# ## GMM

# %%
from sklearn.mixture import GaussianMixture as GMM

X = df_cml[['Area', 'AspectRatio', 'Perimeter', 'Circularity', 'THETA_COX4+4L2','THETA_MTCO1', 'THETA_NDUFA13', 'THETA_NDUFB8', 'THETA_OSCP', 'THETA_SDHA', 'THETA_UqCRC2'  ]]
labels = df2[['patient_type']]

labels.patient_type = labels.patient_type.astype("category")
labels.patient_type = labels.patient_type.cat.codes
labels.patient_type = labels.patient_type.astype("int")

cls = GMM(n_components = 2)
cls.fit(X)
# Out:
# C:\Users\b6071289\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# GaussianMixture(covariance_type='full', init_params='kmeans', max_iter=100,
#                 means_init=None, n_components=2, n_init=1, precisions_init=None,
#                 random_state=None, reg_covar=1e-06, tol=0.001, verbose=0,
#                 verbose_interval=10, warm_start=False, weights_init=None)

# %%
predictLabels = cls.fit_predict(X,X)

print(classification_report(labels.patient_type,predictLabels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.13      0.95      0.24       568
#            1       0.99      0.54      0.70      7618
#
#     accuracy                           0.57      8186
#    macro avg       0.56      0.75      0.47      8186
# weighted avg       0.93      0.57      0.67      8186

# %%
labels = df_cml[['subject_group']]

labels.subject_group = labels.subject_group.astype("category")

labels.subject_group = labels.subject_group.cat.codes

labels.subject_group = labels.subject_group.astype("int")

cls = GMM(n_components = 2)
cls.fit(X)
# Out:
# C:\Users\b6071289\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# GaussianMixture(covariance_type='full', init_params='kmeans', max_iter=100,
#                 means_init=None, n_components=2, n_init=1, precisions_init=None,
#                 random_state=None, reg_covar=1e-06, tol=0.001, verbose=0,
#                 verbose_interval=10, warm_start=False, weights_init=None)

# %%
predictLabels = cls.fit_predict(X,X)

print(classification_report(labels.subject_group,predictLabels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.14      1.00      0.24       569
#            1       0.13      0.95      0.24       568
#            2       0.00      0.00      0.00      2240
#            3       0.00      0.00      0.00       946
#            4       0.00      0.00      0.00       628
#            5       0.00      0.00      0.00      2633
#            6       0.00      0.00      0.00       602
#
#     accuracy                           0.14      8186
#    macro avg       0.04      0.28      0.07      8186
# weighted avg       0.02      0.14      0.03      8186
# C:\Users\b6071289\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
